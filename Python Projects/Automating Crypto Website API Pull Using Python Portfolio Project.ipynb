# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'dc6e9f70-d70f-46b0-8662-c3ed9a7cab29',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-04-24T18:37:27.435Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None, 'total_count': 9810}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 12051, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate', '2017-2018-alt-season', 'us-strategic-crypto-reserve'], 'max_supply': 21000000, 'circulating_supply': 19855590, 'total_supply': 19855590, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-04-24T18:36:00.000Z', 'quote': {'USD': {'price': 93236.23561717682, 'volume_24h': 31280428313.52862, 'volume_change_24h': -39.7699, 'percent_change_1h': 0.28935606, 'percent_change_24h': -0.66053809, 'percent_change_7d': 9.16170629, 'percent_change_30d': 6.11376618, 'percent_change_60d': -2.66150162, 'percent_change_90d': -12.76316984, 'market_cap': 1851260467558.0598, 'market_cap_dominance': 63.4087, 'fully_diluted_market_cap': 1957960947960.71, 'tvl': None, 'last_updated': '2025-04-24T18:36:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 10150, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'ethereum-pow-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', 'sora-ecosystem', 'rsk-rbtc-ecosystem', 'world-liberty-financial-portfolio', 'us-strategic-crypto-reserve'], 'max_supply': None, 'circulating_supply': 120715603.19016117, 'total_supply': 120715603.19016117, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-04-24T18:36:00.000Z', 'quote': {'USD': {'price': 1760.9130439733729, 'volume_24h': 15484617199.381826, 'volume_change_24h': -39.3564, 'percent_change_1h': 0.27452988, 'percent_change_24h': -2.13338056, 'percent_change_7d': 9.32197091, 'percent_change_30d': -14.80257449, 'percent_change_60d': -37.39763479, 'percent_change_90d': -48.12139548, 'market_cap': 212569680268.6685, 'market_cap_dominance': 7.2809, 'fully_diluted_market_cap': 212569680268.67, 'tvl': None, 'last_updated': '2025-04-24T18:36:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 125378, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'usd-stablecoin', 'ethereum-pow-ecosystem', 'fiat-stablecoin', 'tron20-ecosystem', 'rsk-rbtc-ecosystem' ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2025-04-24T18:37:27.435Z           0          None       15             1
#
#   notice  total_count
# 0   None         9810

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'dc6e9f70-d70f-46b0-8662-c3ed9a7cab29',
    }
    
    session = Session()
    session.headers.update(headers)
    
    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df_append = pd.DataFrame(df2)
df = pd.concat([df,df_append])
df

if not os.path.isfile(r'C:\Users\yashv\OneDrive - University of Massachusetts\Portfolio Projects\PortfolioProjects\API1.csv'):
    df.to_csv(r'C:\Users\yashv\OneDrive - University of Massachusetts\Portfolio Projects\PortfolioProjects\API1.csv' , header = 'column_names')
else:
    df.to_csv(r'C:\Users\yashv\OneDrive - University of Massachusetts\Portfolio Projects\PortfolioProjects\API1.csv' , mode = 'a', header = False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed sucessfully !!')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed sucessfully !!
# API Runner completed sucessfully !!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 8
#       6     api_runner()
#       7     print('API Runner completed sucessfully !!')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df3 = pd.read_csv(r'C:\Users\yashv\OneDrive - University of Massachusetts\Portfolio Projects\PortfolioProjects\API1.csv')
df3
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             12051
# 1            1   1027      Ethereum    ETH      ethereum             10150
# 2            2    825   Tether USDt   USDT        tether            125378
# 3            3     52           XRP    XRP           xrp              1594
# 4            4   1839           BNB    BNB           bnb              2492
# 5            5   5426        Solana    SOL        solana               902
# 6            6   3408          USDC   USDC      usd-coin             27334
# 7            7     74      Dogecoin   DOGE      dogecoin              1209
# 8            8   2010       Cardano    ADA       cardano              1506
# 9            9   1958          TRON    TRX          tron              1166
# 10          10  20947           Sui    SUI           sui               612
# 11          11   1975     Chainlink   LINK     chainlink              1997
# 12          12   5805     Avalanche   AVAX     avalanche               907
# 13          13    512       Stellar    XLM       stellar               703
# 14          14   3957  UNUS SED LEO    LEO  unus-sed-leo                60
# 15           0      1       Bitcoin    BTC       bitcoin             12051
# 16           1   1027      Ethereum    ETH      ethereum             10150
# 17           2    825   Tether USDt   USDT        tether            125378
# 18           3     52           XRP    XRP           xrp              1594
# 19           4   1839           BNB    BNB           bnb              2492
# 20           5   5426        Solana    SOL        solana               902
# 21           6   3408          USDC   USDC      usd-coin             27334
# 22           7     74      Dogecoin   DOGE      dogecoin              1209
# 23           8   2010       Cardano    ADA       cardano              1506
# 24           9   1958          TRON    TRX          tron              1166
# 25          10  20947           Sui    SUI           sui               612
# 26          11   1975     Chainlink   LINK     chainlink              1997
# 27          12   5805     Avalanche   AVAX     avalanche               907
# 28          13    512       Stellar    XLM       stellar               703
# 29          14   3957  UNUS SED LEO    LEO  unus-sed-leo                60
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2022-07-12T08:03:11.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2014-08-05T00:00:00.000Z
# 14  2019-05-21T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2013-08-04T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2020-04-10T00:00:00.000Z
# 21  2018-10-08T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2017-10-01T00:00:00.000Z
# 24  2017-09-13T00:00:00.000Z
# 25  2022-07-12T08:03:11.000Z
# 26  2017-09-20T00:00:00.000Z
# 27  2020-07-13T00:00:00.000Z
# 28  2014-08-05T00:00:00.000Z
# 29  2019-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'usd...           NaN
# 3   ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 4   ['marketplace', 'centralized-exchange', 'payme...           NaN
# 5   ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 6   ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 7   ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 8   ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 9   ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 10  ['binance-launchpool', 'coinbase-ventures-port...  1.000000e+10
# 11  ['platform', 'defi', 'oracles', 'smart-contrac...           NaN
# 12  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 13  ['medium-of-exchange', 'enterprise-solutions',...  5.000181e+10
# 14  ['marketplace', 'centralized-exchange', 'disco...           NaN
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 17  ['stablecoin', 'asset-backed-stablecoin', 'usd...           NaN
# 18  ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 19  ['marketplace', 'centralized-exchange', 'payme...           NaN
# 20  ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 21  ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 22  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 23  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 24  ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 25  ['binance-launchpool', 'coinbase-ventures-port...  1.000000e+10
# 26  ['platform', 'defi', 'oracles', 'smart-contrac...           NaN
# 27  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 28  ['medium-of-exchange', 'enterprise-solutions',...  5.000181e+10
# 29  ['marketplace', 'centralized-exchange', 'disco...           NaN
#
#     circulating_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.985559e+07  ...                         63.4087
# 1         1.207156e+08  ...                          7.2809
# 2         1.456481e+11  ...                          4.9898
# 3         5.839417e+10  ...                          4.4023
# 4         1.408905e+08  ...                          2.8821
# 5         5.173125e+08  ...                          2.6914
# 6         6.172840e+10  ...                          2.1140
# 7         1.489886e+11  ...                          0.9178
# 8         3.529030e+10  ...                          0.8809
# 9         9.493978e+10  ...                          0.8029
# 10        3.249983e+09  ...                          0.3703
# 11        6.571000e+08  ...                          0.3375
# 12        4.160921e+08  ...                          0.3170
# 13        3.085973e+10  ...                          0.2948
# 14        9.236185e+08  ...                          0.2917
# 15        1.985559e+07  ...                         63.4087
# 16        1.207156e+08  ...                          7.2809
# 17        1.456481e+11  ...                          4.9898
# 18        5.839417e+10  ...                          4.4023
# 19        1.408905e+08  ...                          2.8821
# 20        5.173125e+08  ...                          2.6914
# 21        6.172840e+10  ...                          2.1140
# 22        1.489886e+11  ...                          0.9178
# 23        3.529030e+10  ...                          0.8809
# 24        9.493978e+10  ...                          0.8029
# 25        3.249983e+09  ...                          0.3703
# 26        6.571000e+08  ...                          0.3375
# 27        4.160921e+08  ...                          0.3170
# 28        3.085973e+10  ...                          0.2948
# 29        9.236185e+08  ...                          0.2917
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         1.957961e+12            NaN
# 1                         2.125697e+11            NaN
# 2                         1.485624e+11            NaN
# 3                         2.201047e+11            NaN
# 4                         8.414369e+10            NaN
# 5                         9.101053e+10            NaN
# 6                         6.172104e+10            NaN
# 7                         2.679662e+10            NaN
# 8                         3.279367e+10            NaN
# 9                         2.344163e+10            NaN
# 10                        3.326375e+10            NaN
# 11                        1.499428e+10            NaN
# 12                        1.592254e+10            NaN
# 13                        1.394698e+10            NaN
# 14                        9.084885e+09            NaN
# 15                        1.957961e+12            NaN
# 16                        2.125697e+11            NaN
# 17                        1.485624e+11            NaN
# 18                        2.201047e+11            NaN
# 19                        8.414369e+10            NaN
# 20                        9.101053e+10            NaN
# 21                        6.172104e+10            NaN
# 22                        2.679662e+10            NaN
# 23                        3.279367e+10            NaN
# 24                        2.344163e+10            NaN
# 25                        3.326375e+10            NaN
# 26                        1.499428e+10            NaN
# 27                        1.592254e+10            NaN
# 28                        1.394698e+10            NaN
# 29                        9.084885e+09            NaN
#
#       quote.USD.last_updated  platform.id  platform.name  platform.symbol  \
# 0   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 1   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 2   2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 3   2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 4   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 5   2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 6   2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 7   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 8   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 9   2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 10  2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 11  2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 12  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 13  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 14  2025-04-24T18:36:00.000Z       1027.0       Ethereum              ETH
# 15  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 16  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 17  2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 18  2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 19  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 20  2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 21  2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 22  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 23  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 24  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 25  2025-04-24T18:35:00.000Z          NaN            NaN              NaN
# 26  2025-04-24T18:35:00.000Z       1027.0       Ethereum              ETH
# 27  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 28  2025-04-24T18:36:00.000Z          NaN            NaN              NaN
# 29  2025-04-24T18:36:00.000Z       1027.0       Ethereum              ETH
#
#    platform.slug                      platform.token_address  \
# 0            NaN                                         NaN
# 1            NaN                                         NaN
# 2       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3            NaN                                         NaN
# 4            NaN                                         NaN
# 5            NaN                                         NaN
# 6       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7            NaN                                         NaN
# 8            NaN                                         NaN
# 9            NaN                                         NaN
# 10           NaN                                         NaN
# 11      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12           NaN                                         NaN
# 13           NaN                                         NaN
# 14      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 15           NaN                                         NaN
# 16           NaN                                         NaN
# 17      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18           NaN                                         NaN
# 19           NaN                                         NaN
# 20           NaN                                         NaN
# 21      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22           NaN                                         NaN
# 23           NaN                                         NaN
# 24           NaN                                         NaN
# 25           NaN                                         NaN
# 26      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 27           NaN                                         NaN
# 28           NaN                                         NaN
# 29      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
#
#                      timestamp
# 0   2025-04-24 15:38:35.359235
# 1   2025-04-24 15:38:35.359235
# 2   2025-04-24 15:38:35.359235
# 3   2025-04-24 15:38:35.359235
# 4   2025-04-24 15:38:35.359235
# 5   2025-04-24 15:38:35.359235
# 6   2025-04-24 15:38:35.359235
# 7   2025-04-24 15:38:35.359235
# 8   2025-04-24 15:38:35.359235
# 9   2025-04-24 15:38:35.359235
# 10  2025-04-24 15:38:35.359235
# 11  2025-04-24 15:38:35.359235
# 12  2025-04-24 15:38:35.359235
# 13  2025-04-24 15:38:35.359235
# 14  2025-04-24 15:38:35.359235
# 15  2025-04-24 14:56:30.889565
# 16  2025-04-24 14:56:30.889565
# 17  2025-04-24 14:56:30.889565
# 18  2025-04-24 14:56:30.889565
# 19  2025-04-24 14:56:30.889565
# 20  2025-04-24 14:56:30.889565
# 21  2025-04-24 14:56:30.889565
# 22  2025-04-24 14:56:30.889565
# 23  2025-04-24 14:56:30.889565
# 24  2025-04-24 14:56:30.889565
# 25  2025-04-24 14:56:30.889565
# 26  2025-04-24 14:56:30.889565
# 27  2025-04-24 14:56:30.889565
# 28  2025-04-24 14:56:30.889565
# 29  2025-04-24 14:56:30.889565
#
# [30 rows x 38 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12051
# 1    1027      Ethereum    ETH      ethereum             10150
# 2     825   Tether USDt   USDT        tether            125378
# 3      52           XRP    XRP           xrp              1594
# 4    1839           BNB    BNB           bnb              2492
# 5    5426        Solana    SOL        solana               902
# 6    3408          USDC   USDC      usd-coin             27334
# 7      74      Dogecoin   DOGE      dogecoin              1209
# 8    2010       Cardano    ADA       cardano              1506
# 9    1958          TRON    TRX          tron              1166
# 10  20947           Sui    SUI           sui               612
# 11   1975     Chainlink   LINK     chainlink              1997
# 12   5805     Avalanche   AVAX     avalanche               907
# 13    512       Stellar    XLM       stellar               703
# 14   3957  UNUS SED LEO    LEO  unus-sed-leo                60
# 0       1       Bitcoin    BTC       bitcoin             12051
# 1    1027      Ethereum    ETH      ethereum             10150
# 2     825   Tether USDt   USDT        tether            125378
# 3      52           XRP    XRP           xrp              1594
# 4    1839           BNB    BNB           bnb              2492
# 5    5426        Solana    SOL        solana               902
# 6    3408          USDC   USDC      usd-coin             27334
# 7      74      Dogecoin   DOGE      dogecoin              1209
# 8    2010       Cardano    ADA       cardano              1506
# 9    1958          TRON    TRX          tron              1166
# 10  20947           Sui    SUI           sui               612
# 11   1975     Chainlink   LINK     chainlink              1997
# 12   5805     Avalanche   AVAX     avalanche               907
# 13    512       Stellar    XLM       stellar               703
# 14   3957  UNUS SED LEO    LEO  unus-sed-leo                60
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2022-07-12T08:03:11.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2014-08-05T00:00:00.000Z
# 14  2019-05-21T00:00:00.000Z
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2022-07-12T08:03:11.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2014-08-05T00:00:00.000Z
# 14  2019-05-21T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...      21,000,000.00
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...                NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp... 100,000,000,000.00
# 4   [marketplace, centralized-exchange, payments, ...                NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [dpos, pos, platform, research, smart-contract...  45,000,000,000.00
# 9   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 10  [binance-launchpool, coinbase-ventures-portfol...  10,000,000,000.00
# 11  [platform, defi, oracles, smart-contracts, eth...                NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...     715,748,719.00
# 13  [medium-of-exchange, enterprise-solutions, dec...  50,001,806,812.00
# 14  [marketplace, centralized-exchange, discount-t...                NaN
# 0   [mineable, pow, sha-256, store-of-value, state...      21,000,000.00
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...                NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp... 100,000,000,000.00
# 4   [marketplace, centralized-exchange, payments, ...                NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [dpos, pos, platform, research, smart-contract...  45,000,000,000.00
# 9   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 10  [binance-launchpool, coinbase-ventures-portfol...  10,000,000,000.00
# 11  [platform, defi, oracles, smart-contracts, eth...                NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...     715,748,719.00
# 13  [medium-of-exchange, enterprise-solutions, dec...  50,001,806,812.00
# 14  [marketplace, centralized-exchange, discount-t...                NaN
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0        19,855,590.00      19,855,590.00            False       NaN
# 1       120,715,603.19     120,715,603.19             True       NaN
# 2   145,648,071,863.18 148,529,468,602.74             True       NaN
# 3    58,394,167,593.00  99,986,232,255.00            False       NaN
# 4       140,890,537.08     140,890,537.08            False       NaN
# 5       517,312,497.66     599,172,556.69             True       NaN
# 6    61,728,403,249.95  61,728,403,249.95            False       NaN
# 7   148,988,556,383.71 148,988,556,383.71             True       NaN
# 8    35,290,300,162.93  44,994,927,344.93            False       NaN
# 9    94,939,784,019.49  94,939,793,706.40             True       NaN
# 10    3,249,982,900.46  10,000,000,000.00            False       NaN
# 11      657,099,970.45   1,000,000,000.00            False       NaN
# 12      416,092,067.06     452,761,567.06            False       NaN
# 13   30,859,730,417.43  50,001,786,892.82            False       NaN
# 14      923,618,473.90     985,239,504.00            False       NaN
# 0        19,855,590.00      19,855,590.00            False       NaN
# 1       120,715,603.19     120,715,603.19             True       NaN
# 2   145,648,071,863.18 148,529,468,602.74             True       NaN
# 3    58,394,167,593.00  99,986,232,255.00            False       NaN
# 4       140,890,537.08     140,890,537.08            False       NaN
# 5       517,312,497.66     599,172,556.69             True       NaN
# 6    61,728,403,249.95  61,728,403,249.95            False       NaN
# 7   148,988,556,383.71 148,988,556,383.71             True       NaN
# 8    35,290,300,162.93  44,994,927,344.93            False       NaN
# 9    94,939,784,019.49  94,939,793,706.40             True       NaN
# 10    3,249,982,900.46  10,000,000,000.00            False       NaN
# 11      657,099,970.45   1,000,000,000.00            False       NaN
# 12      416,092,067.06     452,761,567.06            False       NaN
# 13   30,859,730,417.43  50,001,786,892.82            False       NaN
# 14      923,618,473.90     985,239,504.00            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                  3,249,982,900.46         10,810,661,014.99
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                  3,249,982,900.46         10,810,661,014.99
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2025-04-24T18:36:00.000Z        93,236.24     31,280,428,313.53
# 1       None  2025-04-24T18:36:00.000Z         1,760.91     15,484,617,199.38
# 2       None  2025-04-24T18:35:00.000Z             1.00     70,353,996,109.18
# 3       None  2025-04-24T18:35:00.000Z             2.20      4,239,245,548.98
# 4       None  2025-04-24T18:36:00.000Z           597.23      1,593,111,078.89
# 5       None  2025-04-24T18:35:00.000Z           151.89      3,856,669,384.28
# 6       None  2025-04-24T18:35:00.000Z             1.00     11,243,387,521.00
# 7       None  2025-04-24T18:36:00.000Z             0.18      1,409,523,130.95
# 8       None  2025-04-24T18:36:00.000Z             0.73      1,013,766,060.31
# 9       None  2025-04-24T18:36:00.000Z             0.25        591,523,123.21
# 10      None  2025-04-24T18:35:00.000Z             3.33      2,940,829,834.37
# 11      None  2025-04-24T18:35:00.000Z            14.99        421,150,282.50
# 12      None  2025-04-24T18:36:00.000Z            22.25        328,164,592.69
# 13      None  2025-04-24T18:36:00.000Z             0.28        248,925,187.67
# 14      None  2025-04-24T18:36:00.000Z             9.22          2,874,265.36
# 0       None  2025-04-24T18:36:00.000Z        93,236.24     31,280,428,313.53
# 1       None  2025-04-24T18:36:00.000Z         1,760.91     15,484,617,199.38
# 2       None  2025-04-24T18:35:00.000Z             1.00     70,353,996,109.18
# 3       None  2025-04-24T18:35:00.000Z             2.20      4,239,245,548.98
# 4       None  2025-04-24T18:36:00.000Z           597.23      1,593,111,078.89
# 5       None  2025-04-24T18:35:00.000Z           151.89      3,856,669,384.28
# 6       None  2025-04-24T18:35:00.000Z             1.00     11,243,387,521.00
# 7       None  2025-04-24T18:36:00.000Z             0.18      1,409,523,130.95
# 8       None  2025-04-24T18:36:00.000Z             0.73      1,013,766,060.31
# 9       None  2025-04-24T18:36:00.000Z             0.25        591,523,123.21
# 10      None  2025-04-24T18:35:00.000Z             3.33      2,940,829,834.37
# 11      None  2025-04-24T18:35:00.000Z            14.99        421,150,282.50
# 12      None  2025-04-24T18:36:00.000Z            22.25        328,164,592.69
# 13      None  2025-04-24T18:36:00.000Z             0.28        248,925,187.67
# 14      None  2025-04-24T18:36:00.000Z             9.22          2,874,265.36
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                        -39.77                         0.29
# 1                        -39.36                         0.27
# 2                        -32.38                        -0.01
# 3                        -27.67                         0.27
# 4                        -15.26                         0.01
# 5                        -28.36                         1.06
# 6                        -29.09                        -0.00
# 7                        -32.80                         0.45
# 8                         -7.76                         0.57
# 9                        -22.32                         0.14
# 10                        -4.12                         1.08
# 11                       -27.60                         0.95
# 12                       -33.06                         0.60
# 13                       -20.46                         0.64
# 14                       -41.30                        -0.03
# 0                        -39.77                         0.29
# 1                        -39.36                         0.27
# 2                        -32.38                        -0.01
# 3                        -27.67                         0.27
# 4                        -15.26                         0.01
# 5                        -28.36                         1.06
# 6                        -29.09                        -0.00
# 7                        -32.80                         0.45
# 8                         -7.76                         0.57
# 9                        -22.32                         0.14
# 10                        -4.12                         1.08
# 11                       -27.60                         0.95
# 12                       -33.06                         0.60
# 13                       -20.46                         0.64
# 14                       -41.30                        -0.03
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                          -0.66                         9.16
# 1                          -2.13                         9.32
# 2                          -0.00                         0.02
# 3                          -1.75                         4.95
# 4                          -1.64                         0.76
# 5                           0.11                        12.30
# 6                          -0.02                        -0.01
# 7                          -0.44                        13.23
# 8                           2.94                        16.06
# 9                           0.50                        -1.04
# 10                          8.78                        53.84
# 11                          0.03                        18.45
# 12                         -0.97                        14.60
# 13                          3.12                        15.66
# 14                          1.59                         2.03
# 0                          -0.66                         9.16
# 1                          -2.13                         9.32
# 2                          -0.00                         0.02
# 3                          -1.75                         4.95
# 4                          -1.64                         0.76
# 5                           0.11                        12.30
# 6                          -0.02                        -0.01
# 7                          -0.44                        13.23
# 8                           2.94                        16.06
# 9                           0.50                        -1.04
# 10                          8.78                        53.84
# 11                          0.03                        18.45
# 12                         -0.97                        14.60
# 13                          3.12                        15.66
# 14                          1.59                         2.03
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                           6.11                         -2.66
# 1                         -14.80                        -37.40
# 2                          -0.02                          0.01
# 3                         -10.34                        -14.11
# 4                          -5.42                         -8.61
# 5                           4.77                         -9.89
# 6                          -0.01                         -0.01
# 7                          -6.59                        -25.96
# 8                          -2.92                         -5.08
# 9                           8.35                          1.15
# 10                         35.41                         -0.16
# 11                         -2.88                        -15.02
# 12                         -3.39                         -9.70
# 13                         -5.14                        -15.67
# 14                         -5.53                         -5.55
# 0                           6.11                         -2.66
# 1                         -14.80                        -37.40
# 2                          -0.02                          0.01
# 3                         -10.34                        -14.11
# 4                          -5.42                         -8.61
# 5                           4.77                         -9.89
# 6                          -0.01                         -0.01
# 7                          -6.59                        -25.96
# 8                          -2.92                         -5.08
# 9                           8.35                          1.15
# 10                         35.41                         -0.16
# 11                         -2.88                        -15.02
# 12                         -3.39                         -9.70
# 13                         -5.14                        -15.67
# 14                         -5.53                         -5.55
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                         -12.76  1,851,260,467,558.06
# 1                         -48.12    212,569,680,268.67
# 2                           0.01    145,680,409,917.07
# 3                         -30.28    128,528,299,689.27
# 4                         -13.05     84,143,689,396.16
# 5                         -42.38     78,576,504,608.35
# 6                           0.01     61,721,036,982.12
# 7                         -49.98     26,796,616,383.77
# 8                         -26.95     25,717,746,799.59
# 9                          -4.77     23,441,630,279.81
# 10                        -24.95     10,810,661,014.99
# 11                        -42.40      9,852,737,896.33
# 12                        -39.46      9,256,378,801.50
# 13                        -36.65      8,607,692,366.19
# 14                         -5.46      8,516,678,086.74
# 0                         -12.76  1,851,260,467,558.06
# 1                         -48.12    212,569,680,268.67
# 2                           0.01    145,680,409,917.07
# 3                         -30.28    128,528,299,689.27
# 4                         -13.05     84,143,689,396.16
# 5                         -42.38     78,576,504,608.35
# 6                           0.01     61,721,036,982.12
# 7                         -49.98     26,796,616,383.77
# 8                         -26.95     25,717,746,799.59
# 9                          -4.77     23,441,630,279.81
# 10                        -24.95     10,810,661,014.99
# 11                        -42.40      9,852,737,896.33
# 12                        -39.46      9,256,378,801.50
# 13                        -36.65      8,607,692,366.19
# 14                         -5.46      8,516,678,086.74
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            63.41                1,957,960,947,960.71
# 1                             7.28                  212,569,680,268.67
# 2                             4.99                  148,562,446,409.44
# 3                             4.40                  220,104,686,798.69
# 4                             2.88                   84,143,689,396.16
# 5                             2.69                   91,010,531,109.73
# 6                             2.11                   61,721,036,982.12
# 7                             0.92                   26,796,616,383.77
# 8                             0.88                   32,793,674,200.52
# 9                             0.80                   23,441,632,671.61
# 10                            0.37                   33,263,747,367.59
# 11                            0.34                   14,994,275,360.48
# 12                            0.32                   15,922,536,847.43
# 13                            0.29                   13,946,984,143.07
# 14                            0.29                    9,084,885,080.83
# 0                            63.41                1,957,960,947,960.71
# 1                             7.28                  212,569,680,268.67
# 2                             4.99                  148,562,446,409.44
# 3                             4.40                  220,104,686,798.69
# 4                             2.88                   84,143,689,396.16
# 5                             2.69                   91,010,531,109.73
# 6                             2.11                   61,721,036,982.12
# 7                             0.92                   26,796,616,383.77
# 8                             0.88                   32,793,674,200.52
# 9                             0.80                   23,441,632,671.61
# 10                            0.37                   33,263,747,367.59
# 11                            0.34                   14,994,275,360.48
# 12                            0.32                   15,922,536,847.43
# 13                            0.29                   13,946,984,143.07
# 14                            0.29                    9,084,885,080.83
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 1           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 2           None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 3           None  2025-04-24T18:35:00.000Z          NaN           NaN
# 4           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 5           None  2025-04-24T18:35:00.000Z          NaN           NaN
# 6           None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 7           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 8           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 9           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 10          None  2025-04-24T18:35:00.000Z          NaN           NaN
# 11          None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 12          None  2025-04-24T18:36:00.000Z          NaN           NaN
# 13          None  2025-04-24T18:36:00.000Z          NaN           NaN
# 14          None  2025-04-24T18:36:00.000Z     1,027.00      Ethereum
# 0           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 1           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 2           None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 3           None  2025-04-24T18:35:00.000Z          NaN           NaN
# 4           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 5           None  2025-04-24T18:35:00.000Z          NaN           NaN
# 6           None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 7           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 8           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 9           None  2025-04-24T18:36:00.000Z          NaN           NaN
# 10          None  2025-04-24T18:35:00.000Z          NaN           NaN
# 11          None  2025-04-24T18:35:00.000Z     1,027.00      Ethereum
# 12          None  2025-04-24T18:36:00.000Z          NaN           NaN
# 13          None  2025-04-24T18:36:00.000Z          NaN           NaN
# 14          None  2025-04-24T18:36:00.000Z     1,027.00      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
#
#                     timestamp
# 0  2025-04-24 15:38:35.359235
# 1  2025-04-24 15:38:35.359235
# 2  2025-04-24 15:38:35.359235
# 3  2025-04-24 15:38:35.359235
# 4  2025-04-24 15:38:35.359235
# 5  2025-04-24 15:38:35.359235
# 6  2025-04-24 15:38:35.359235
# 7  2025-04-24 15:38:35.359235
# 8  2025-04-24 15:38:35.359235
# 9  2025-04-24 15:38:35.359235
# 10 2025-04-24 15:38:35.359235
# 11 2025-04-24 15:38:35.359235
# 12 2025-04-24 15:38:35.359235
# 13 2025-04-24 15:38:35.359235
# 14 2025-04-24 15:38:35.359235
# 0  2025-04-24 14:56:30.889565
# 1  2025-04-24 14:56:30.889565
# 2  2025-04-24 14:56:30.889565
# 3  2025-04-24 14:56:30.889565
# 4  2025-04-24 14:56:30.889565
# 5  2025-04-24 14:56:30.889565
# 6  2025-04-24 14:56:30.889565
# 7  2025-04-24 14:56:30.889565
# 8  2025-04-24 14:56:30.889565
# 9  2025-04-24 14:56:30.889565
# 10 2025-04-24 14:56:30.889565
# 11 2025-04-24 14:56:30.889565
# 12 2025-04-24 14:56:30.889565
# 13 2025-04-24 14:56:30.889565
# 14 2025-04-24 14:56:30.889565

# %%
df3 = df.groupby('name', sort = False)[['quote.USD.percent_change_1h' , 'quote.USD.percent_change_24h' , 'quote.USD.percent_change_7d' , 'quote.USD.percent_change_30d' , 'quote.USD.percent_change_60d' , 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                              0.29                         -0.66
# Ethereum                             0.27                         -2.13
# Tether USDt                         -0.01                         -0.00
# XRP                                  0.27                         -1.75
# BNB                                  0.01                         -1.64
# Solana                               1.06                          0.11
# USDC                                -0.00                         -0.02
# Dogecoin                             0.45                         -0.44
# Cardano                              0.57                          2.94
# TRON                                 0.14                          0.50
# Sui                                  1.08                          8.78
# Chainlink                            0.95                          0.03
# Avalanche                            0.60                         -0.97
# Stellar                              0.64                          3.12
# UNUS SED LEO                        -0.03                          1.59
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                              9.16                          6.11
# Ethereum                             9.32                        -14.80
# Tether USDt                          0.02                         -0.02
# XRP                                  4.95                        -10.34
# BNB                                  0.76                         -5.42
# Solana                              12.30                          4.77
# USDC                                -0.01                         -0.01
# Dogecoin                            13.23                         -6.59
# Cardano                             16.06                         -2.92
# TRON                                -1.04                          8.35
# Sui                                 53.84                         35.41
# Chainlink                           18.45                         -2.88
# Avalanche                           14.60                         -3.39
# Stellar                             15.66                         -5.14
# UNUS SED LEO                         2.03                         -5.53
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                              -2.66                        -12.76
# Ethereum                            -37.40                        -48.12
# Tether USDt                           0.01                          0.01
# XRP                                 -14.11                        -30.28
# BNB                                  -8.61                        -13.05
# Solana                               -9.89                        -42.38
# USDC                                 -0.01                          0.01
# Dogecoin                            -25.96                        -49.98
# Cardano                              -5.08                        -26.95
# TRON                                  1.15                         -4.77
# Sui                                  -0.16                        -24.95
# Chainlink                           -15.02                        -42.40
# Avalanche                            -9.70                        -39.46
# Stellar                             -15.67                        -36.65
# UNUS SED LEO                         -5.55                         -5.46

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h      0.29
#               quote.USD.percent_change_24h    -0.66
#               quote.USD.percent_change_7d      9.16
#               quote.USD.percent_change_30d     6.11
#               quote.USD.percent_change_60d    -2.66
#               quote.USD.percent_change_90d   -12.76
# Ethereum      quote.USD.percent_change_1h      0.27
#               quote.USD.percent_change_24h    -2.13
#               quote.USD.percent_change_7d      9.32
#               quote.USD.percent_change_30d   -14.80
#               quote.USD.percent_change_60d   -37.40
#               quote.USD.percent_change_90d   -48.12
# Tether USDt   quote.USD.percent_change_1h     -0.01
#               quote.USD.percent_change_24h    -0.00
#               quote.USD.percent_change_7d      0.02
#               quote.USD.percent_change_30d    -0.02
#               quote.USD.percent_change_60d     0.01
#               quote.USD.percent_change_90d     0.01
# XRP           quote.USD.percent_change_1h      0.27
#               quote.USD.percent_change_24h    -1.75
#               quote.USD.percent_change_7d      4.95
#               quote.USD.percent_change_30d   -10.34
#               quote.USD.percent_change_60d   -14.11
#               quote.USD.percent_change_90d   -30.28
# BNB           quote.USD.percent_change_1h      0.01
#               quote.USD.percent_change_24h    -1.64
#               quote.USD.percent_change_7d      0.76
#               quote.USD.percent_change_30d    -5.42
#               quote.USD.percent_change_60d    -8.61
#               quote.USD.percent_change_90d   -13.05
# Solana        quote.USD.percent_change_1h      1.06
#               quote.USD.percent_change_24h     0.11
#               quote.USD.percent_change_7d     12.30
#               quote.USD.percent_change_30d     4.77
#               quote.USD.percent_change_60d    -9.89
#               quote.USD.percent_change_90d   -42.38
# USDC          quote.USD.percent_change_1h     -0.00
#               quote.USD.percent_change_24h    -0.02
#               quote.USD.percent_change_7d     -0.01
#               quote.USD.percent_change_30d    -0.01
#               quote.USD.percent_change_60d    -0.01
#               quote.USD.percent_change_90d     0.01
# Dogecoin      quote.USD.percent_change_1h      0.45
#               quote.USD.percent_change_24h    -0.44
#               quote.USD.percent_change_7d     13.23
#               quote.USD.percent_change_30d    -6.59
#               quote.USD.percent_change_60d   -25.96
#               quote.USD.percent_change_90d   -49.98
# Cardano       quote.USD.percent_change_1h      0.57
#               quote.USD.percent_change_24h     2.94
#               quote.USD.percent_change_7d     16.06
#               quote.USD.percent_change_30d    -2.92
#               quote.USD.percent_change_60d    -5.08
#               quote.USD.percent_change_90d   -26.95
# TRON          quote.USD.percent_change_1h      0.14
#               quote.USD.percent_change_24h     0.50
#               quote.USD.percent_change_7d     -1.04
#               quote.USD.percent_change_30d     8.35
#               quote.USD.percent_change_60d     1.15
#               quote.USD.percent_change_90d    -4.77
# Sui           quote.USD.percent_change_1h      1.08
#               quote.USD.percent_change_24h     8.78
#               quote.USD.percent_change_7d     53.84
#               quote.USD.percent_change_30d    35.41
#               quote.USD.percent_change_60d    -0.16
#               quote.USD.percent_change_90d   -24.95
# Chainlink     quote.USD.percent_change_1h      0.95
#               quote.USD.percent_change_24h     0.03
#               quote.USD.percent_change_7d     18.45
#               quote.USD.percent_change_30d    -2.88
#               quote.USD.percent_change_60d   -15.02
#               quote.USD.percent_change_90d   -42.40
# Avalanche     quote.USD.percent_change_1h      0.60
#               quote.USD.percent_change_24h    -0.97
#               quote.USD.percent_change_7d     14.60
#               quote.USD.percent_change_30d    -3.39
#               quote.USD.percent_change_60d    -9.70
#               quote.USD.percent_change_90d   -39.46
# Stellar       quote.USD.percent_change_1h      0.64
#               quote.USD.percent_change_24h     3.12
#               quote.USD.percent_change_7d     15.66
#               quote.USD.percent_change_30d    -5.14
#               quote.USD.percent_change_60d   -15.67
#               quote.USD.percent_change_90d   -36.65
# UNUS SED LEO  quote.USD.percent_change_1h     -0.03
#               quote.USD.percent_change_24h     1.59
#               quote.USD.percent_change_7d      2.03
#               quote.USD.percent_change_30d    -5.53
#               quote.USD.percent_change_60d    -5.55
#               quote.USD.percent_change_90d    -5.46
# dtype: float64

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                            values
# name
# Bitcoin      quote.USD.percent_change_1h     0.29
#              quote.USD.percent_change_24h   -0.66
#              quote.USD.percent_change_7d     9.16
#              quote.USD.percent_change_30d    6.11
#              quote.USD.percent_change_60d   -2.66
#              quote.USD.percent_change_90d  -12.76
# Ethereum     quote.USD.percent_change_1h     0.27
#              quote.USD.percent_change_24h   -2.13
#              quote.USD.percent_change_7d     9.32
#              quote.USD.percent_change_30d  -14.80
#              quote.USD.percent_change_60d  -37.40
#              quote.USD.percent_change_90d  -48.12
# Tether USDt  quote.USD.percent_change_1h    -0.01
#              quote.USD.percent_change_24h   -0.00
#              quote.USD.percent_change_7d     0.02
#              quote.USD.percent_change_30d   -0.02
#              quote.USD.percent_change_60d    0.01
#              quote.USD.percent_change_90d    0.01
# XRP          quote.USD.percent_change_1h     0.27
#              quote.USD.percent_change_24h   -1.75
#              quote.USD.percent_change_7d     4.95
#              quote.USD.percent_change_30d  -10.34
#              quote.USD.percent_change_60d  -14.11
#              quote.USD.percent_change_90d  -30.28
# BNB          quote.USD.percent_change_1h     0.01
#              quote.USD.percent_change_24h   -1.64
#              quote.USD.percent_change_7d     0.76
#              quote.USD.percent_change_30d   -5.42
#              quote.USD.percent_change_60d   -8.61
#              quote.USD.percent_change_90d  -13.05
# Solana       quote.USD.percent_change_1h     1.06
#              quote.USD.percent_change_24h    0.11
#              quote.USD.percent_change_7d    12.30
#              quote.USD.percent_change_30d    4.77
#              quote.USD.percent_change_60d   -9.89
#              quote.USD.percent_change_90d  -42.38
# USDC         quote.USD.percent_change_1h    -0.00
#              quote.USD.percent_change_24h   -0.02
#              quote.USD.percent_change_7d    -0.01
#              quote.USD.percent_change_30d   -0.01
#              quote.USD.percent_change_60d   -0.01
#              quote.USD.percent_change_90d    0.01
# Dogecoin     quote.USD.percent_change_1h     0.45
#              quote.USD.percent_change_24h   -0.44
#              quote.USD.percent_change_7d    13.23
#              quote.USD.percent_change_30d   -6.59
#              quote.USD.percent_change_60d  -25.96
#              quote.USD.percent_change_90d  -49.98
# Cardano      quote.USD.percent_change_1h     0.57
#              quote.USD.percent_change_24h    2.94
#              quote.USD.percent_change_7d    16.06
#              quote.USD.percent_change_30d   -2.92
#              quote.USD.percent_change_60d   -5.08
#              quote.USD.percent_change_90d  -26.95
# TRON         quote.USD.percent_change_1h     0.14
#              quote.USD.percent_change_24h    0.50
#              quote.USD.percent_change_7d    -1.04
#              quote.USD.percent_change_30d    8.35
#              quote.USD.percent_change_60d    1.15
#              quote.USD.percent_change_90d   -4.77
# Sui          quote.USD.percent_change_1h     1.08
#              quote.USD.percent_change_24h    8.78
#              quote.USD.percent_change_7d    53.84
#              quote.USD.percent_change_30d   35.41
#              quote.USD.percent_change_60d   -0.16
#              quote.USD.percent_change_90d  -24.95
# Chainlink    quote.USD.percent_change_1h     0.95
#              quote.USD.percent_change_24h    0.03
#              quote.USD.percent_change_7d    18.45
#              quote.USD.percent_change_30d   -2.88
#              quote.USD.percent_change_60d  -15.02
#              quote.USD.percent_change_90d  -42.40
# Avalanche    quote.USD.percent_change_1h     0.60
#              quote.USD.percent_change_24h   -0.97
#              quote.USD.percent_change_7d    14.60
#              quote.USD.percent_change_30d   -3.39
#              quote.USD.percent_change_60d   -9.70
#              quote.USD.percent_change_90d  -39.46
# Stellar      quote.USD.percent_change_1h     0.64
#              quote.USD.percent_change_24h    3.12
#              quote.USD.percent_change_7d    15.66
#              quote.USD.percent_change_30d   -5.14
#              quote.USD.percent_change_60d  -15.67
#              quote.USD.percent_change_90d  -36.65
# UNUS SED LEO quote.USD.percent_change_1h    -0.03
#              quote.USD.percent_change_24h    1.59
#              quote.USD.percent_change_7d     2.03
#              quote.USD.percent_change_30d   -5.53
#              quote.USD.percent_change_60d   -5.55
#              quote.USD.percent_change_90d   -5.46

# %%
df5 = df5.reset_index()
df5
# Out:
#             name                       level_1  values
# 0        Bitcoin   quote.USD.percent_change_1h    0.29
# 1        Bitcoin  quote.USD.percent_change_24h   -0.66
# 2        Bitcoin   quote.USD.percent_change_7d    9.16
# 3        Bitcoin  quote.USD.percent_change_30d    6.11
# 4        Bitcoin  quote.USD.percent_change_60d   -2.66
# 5        Bitcoin  quote.USD.percent_change_90d  -12.76
# 6       Ethereum   quote.USD.percent_change_1h    0.27
# 7       Ethereum  quote.USD.percent_change_24h   -2.13
# 8       Ethereum   quote.USD.percent_change_7d    9.32
# 9       Ethereum  quote.USD.percent_change_30d  -14.80
# 10      Ethereum  quote.USD.percent_change_60d  -37.40
# 11      Ethereum  quote.USD.percent_change_90d  -48.12
# 12   Tether USDt   quote.USD.percent_change_1h   -0.01
# 13   Tether USDt  quote.USD.percent_change_24h   -0.00
# 14   Tether USDt   quote.USD.percent_change_7d    0.02
# 15   Tether USDt  quote.USD.percent_change_30d   -0.02
# 16   Tether USDt  quote.USD.percent_change_60d    0.01
# 17   Tether USDt  quote.USD.percent_change_90d    0.01
# 18           XRP   quote.USD.percent_change_1h    0.27
# 19           XRP  quote.USD.percent_change_24h   -1.75
# 20           XRP   quote.USD.percent_change_7d    4.95
# 21           XRP  quote.USD.percent_change_30d  -10.34
# 22           XRP  quote.USD.percent_change_60d  -14.11
# 23           XRP  quote.USD.percent_change_90d  -30.28
# 24           BNB   quote.USD.percent_change_1h    0.01
# 25           BNB  quote.USD.percent_change_24h   -1.64
# 26           BNB   quote.USD.percent_change_7d    0.76
# 27           BNB  quote.USD.percent_change_30d   -5.42
# 28           BNB  quote.USD.percent_change_60d   -8.61
# 29           BNB  quote.USD.percent_change_90d  -13.05
# 30        Solana   quote.USD.percent_change_1h    1.06
# 31        Solana  quote.USD.percent_change_24h    0.11
# 32        Solana   quote.USD.percent_change_7d   12.30
# 33        Solana  quote.USD.percent_change_30d    4.77
# 34        Solana  quote.USD.percent_change_60d   -9.89
# 35        Solana  quote.USD.percent_change_90d  -42.38
# 36          USDC   quote.USD.percent_change_1h   -0.00
# 37          USDC  quote.USD.percent_change_24h   -0.02
# 38          USDC   quote.USD.percent_change_7d   -0.01
# 39          USDC  quote.USD.percent_change_30d   -0.01
# 40          USDC  quote.USD.percent_change_60d   -0.01
# 41          USDC  quote.USD.percent_change_90d    0.01
# 42      Dogecoin   quote.USD.percent_change_1h    0.45
# 43      Dogecoin  quote.USD.percent_change_24h   -0.44
# 44      Dogecoin   quote.USD.percent_change_7d   13.23
# 45      Dogecoin  quote.USD.percent_change_30d   -6.59
# 46      Dogecoin  quote.USD.percent_change_60d  -25.96
# 47      Dogecoin  quote.USD.percent_change_90d  -49.98
# 48       Cardano   quote.USD.percent_change_1h    0.57
# 49       Cardano  quote.USD.percent_change_24h    2.94
# 50       Cardano   quote.USD.percent_change_7d   16.06
# 51       Cardano  quote.USD.percent_change_30d   -2.92
# 52       Cardano  quote.USD.percent_change_60d   -5.08
# 53       Cardano  quote.USD.percent_change_90d  -26.95
# 54          TRON   quote.USD.percent_change_1h    0.14
# 55          TRON  quote.USD.percent_change_24h    0.50
# 56          TRON   quote.USD.percent_change_7d   -1.04
# 57          TRON  quote.USD.percent_change_30d    8.35
# 58          TRON  quote.USD.percent_change_60d    1.15
# 59          TRON  quote.USD.percent_change_90d   -4.77
# 60           Sui   quote.USD.percent_change_1h    1.08
# 61           Sui  quote.USD.percent_change_24h    8.78
# 62           Sui   quote.USD.percent_change_7d   53.84
# 63           Sui  quote.USD.percent_change_30d   35.41
# 64           Sui  quote.USD.percent_change_60d   -0.16
# 65           Sui  quote.USD.percent_change_90d  -24.95
# 66     Chainlink   quote.USD.percent_change_1h    0.95
# 67     Chainlink  quote.USD.percent_change_24h    0.03
# 68     Chainlink   quote.USD.percent_change_7d   18.45
# 69     Chainlink  quote.USD.percent_change_30d   -2.88
# 70     Chainlink  quote.USD.percent_change_60d  -15.02
# 71     Chainlink  quote.USD.percent_change_90d  -42.40
# 72     Avalanche   quote.USD.percent_change_1h    0.60
# 73     Avalanche  quote.USD.percent_change_24h   -0.97
# 74     Avalanche   quote.USD.percent_change_7d   14.60
# 75     Avalanche  quote.USD.percent_change_30d   -3.39
# 76     Avalanche  quote.USD.percent_change_60d   -9.70
# 77     Avalanche  quote.USD.percent_change_90d  -39.46
# 78       Stellar   quote.USD.percent_change_1h    0.64
# 79       Stellar  quote.USD.percent_change_24h    3.12
# 80       Stellar   quote.USD.percent_change_7d   15.66
# 81       Stellar  quote.USD.percent_change_30d   -5.14
# 82       Stellar  quote.USD.percent_change_60d  -15.67
# 83       Stellar  quote.USD.percent_change_90d  -36.65
# 84  UNUS SED LEO   quote.USD.percent_change_1h   -0.03
# 85  UNUS SED LEO  quote.USD.percent_change_24h    1.59
# 86  UNUS SED LEO   quote.USD.percent_change_7d    2.03
# 87  UNUS SED LEO  quote.USD.percent_change_30d   -5.53
# 88  UNUS SED LEO  quote.USD.percent_change_60d   -5.55
# 89  UNUS SED LEO  quote.USD.percent_change_90d   -5.46

# %%
df5 = df5.rename(columns={'level_1' : 'percent_change'})
df5
# Out:
#             name                percent_change  values
# 0        Bitcoin   quote.USD.percent_change_1h    0.29
# 1        Bitcoin  quote.USD.percent_change_24h   -0.66
# 2        Bitcoin   quote.USD.percent_change_7d    9.16
# 3        Bitcoin  quote.USD.percent_change_30d    6.11
# 4        Bitcoin  quote.USD.percent_change_60d   -2.66
# 5        Bitcoin  quote.USD.percent_change_90d  -12.76
# 6       Ethereum   quote.USD.percent_change_1h    0.27
# 7       Ethereum  quote.USD.percent_change_24h   -2.13
# 8       Ethereum   quote.USD.percent_change_7d    9.32
# 9       Ethereum  quote.USD.percent_change_30d  -14.80
# 10      Ethereum  quote.USD.percent_change_60d  -37.40
# 11      Ethereum  quote.USD.percent_change_90d  -48.12
# 12   Tether USDt   quote.USD.percent_change_1h   -0.01
# 13   Tether USDt  quote.USD.percent_change_24h   -0.00
# 14   Tether USDt   quote.USD.percent_change_7d    0.02
# 15   Tether USDt  quote.USD.percent_change_30d   -0.02
# 16   Tether USDt  quote.USD.percent_change_60d    0.01
# 17   Tether USDt  quote.USD.percent_change_90d    0.01
# 18           XRP   quote.USD.percent_change_1h    0.27
# 19           XRP  quote.USD.percent_change_24h   -1.75
# 20           XRP   quote.USD.percent_change_7d    4.95
# 21           XRP  quote.USD.percent_change_30d  -10.34
# 22           XRP  quote.USD.percent_change_60d  -14.11
# 23           XRP  quote.USD.percent_change_90d  -30.28
# 24           BNB   quote.USD.percent_change_1h    0.01
# 25           BNB  quote.USD.percent_change_24h   -1.64
# 26           BNB   quote.USD.percent_change_7d    0.76
# 27           BNB  quote.USD.percent_change_30d   -5.42
# 28           BNB  quote.USD.percent_change_60d   -8.61
# 29           BNB  quote.USD.percent_change_90d  -13.05
# 30        Solana   quote.USD.percent_change_1h    1.06
# 31        Solana  quote.USD.percent_change_24h    0.11
# 32        Solana   quote.USD.percent_change_7d   12.30
# 33        Solana  quote.USD.percent_change_30d    4.77
# 34        Solana  quote.USD.percent_change_60d   -9.89
# 35        Solana  quote.USD.percent_change_90d  -42.38
# 36          USDC   quote.USD.percent_change_1h   -0.00
# 37          USDC  quote.USD.percent_change_24h   -0.02
# 38          USDC   quote.USD.percent_change_7d   -0.01
# 39          USDC  quote.USD.percent_change_30d   -0.01
# 40          USDC  quote.USD.percent_change_60d   -0.01
# 41          USDC  quote.USD.percent_change_90d    0.01
# 42      Dogecoin   quote.USD.percent_change_1h    0.45
# 43      Dogecoin  quote.USD.percent_change_24h   -0.44
# 44      Dogecoin   quote.USD.percent_change_7d   13.23
# 45      Dogecoin  quote.USD.percent_change_30d   -6.59
# 46      Dogecoin  quote.USD.percent_change_60d  -25.96
# 47      Dogecoin  quote.USD.percent_change_90d  -49.98
# 48       Cardano   quote.USD.percent_change_1h    0.57
# 49       Cardano  quote.USD.percent_change_24h    2.94
# 50       Cardano   quote.USD.percent_change_7d   16.06
# 51       Cardano  quote.USD.percent_change_30d   -2.92
# 52       Cardano  quote.USD.percent_change_60d   -5.08
# 53       Cardano  quote.USD.percent_change_90d  -26.95
# 54          TRON   quote.USD.percent_change_1h    0.14
# 55          TRON  quote.USD.percent_change_24h    0.50
# 56          TRON   quote.USD.percent_change_7d   -1.04
# 57          TRON  quote.USD.percent_change_30d    8.35
# 58          TRON  quote.USD.percent_change_60d    1.15
# 59          TRON  quote.USD.percent_change_90d   -4.77
# 60           Sui   quote.USD.percent_change_1h    1.08
# 61           Sui  quote.USD.percent_change_24h    8.78
# 62           Sui   quote.USD.percent_change_7d   53.84
# 63           Sui  quote.USD.percent_change_30d   35.41
# 64           Sui  quote.USD.percent_change_60d   -0.16
# 65           Sui  quote.USD.percent_change_90d  -24.95
# 66     Chainlink   quote.USD.percent_change_1h    0.95
# 67     Chainlink  quote.USD.percent_change_24h    0.03
# 68     Chainlink   quote.USD.percent_change_7d   18.45
# 69     Chainlink  quote.USD.percent_change_30d   -2.88
# 70     Chainlink  quote.USD.percent_change_60d  -15.02
# 71     Chainlink  quote.USD.percent_change_90d  -42.40
# 72     Avalanche   quote.USD.percent_change_1h    0.60
# 73     Avalanche  quote.USD.percent_change_24h   -0.97
# 74     Avalanche   quote.USD.percent_change_7d   14.60
# 75     Avalanche  quote.USD.percent_change_30d   -3.39
# 76     Avalanche  quote.USD.percent_change_60d   -9.70
# 77     Avalanche  quote.USD.percent_change_90d  -39.46
# 78       Stellar   quote.USD.percent_change_1h    0.64
# 79       Stellar  quote.USD.percent_change_24h    3.12
# 80       Stellar   quote.USD.percent_change_7d   15.66
# 81       Stellar  quote.USD.percent_change_30d   -5.14
# 82       Stellar  quote.USD.percent_change_60d  -15.67
# 83       Stellar  quote.USD.percent_change_90d  -36.65
# 84  UNUS SED LEO   quote.USD.percent_change_1h   -0.03
# 85  UNUS SED LEO  quote.USD.percent_change_24h    1.59
# 86  UNUS SED LEO   quote.USD.percent_change_7d    2.03
# 87  UNUS SED LEO  quote.USD.percent_change_30d   -5.53
# 88  UNUS SED LEO  quote.USD.percent_change_60d   -5.55
# 89  UNUS SED LEO  quote.USD.percent_change_90d   -5.46

# %%
df5['percent_change'] = df5['percent_change'].replace(['quote.USD.percent_change_1h' , 'quote.USD.percent_change_24h' , 'quote.USD.percent_change_7d' , 'quote.USD.percent_change_30d' , 'quote.USD.percent_change_60d' , 'quote.USD.percent_change_90d'],['1h' , '24h' , '7d' , '30d' , '60d' , '90d'])
df5
# Out:
#             name percent_change  values
# 0        Bitcoin             1h    0.29
# 1        Bitcoin            24h   -0.66
# 2        Bitcoin             7d    9.16
# 3        Bitcoin            30d    6.11
# 4        Bitcoin            60d   -2.66
# 5        Bitcoin            90d  -12.76
# 6       Ethereum             1h    0.27
# 7       Ethereum            24h   -2.13
# 8       Ethereum             7d    9.32
# 9       Ethereum            30d  -14.80
# 10      Ethereum            60d  -37.40
# 11      Ethereum            90d  -48.12
# 12   Tether USDt             1h   -0.01
# 13   Tether USDt            24h   -0.00
# 14   Tether USDt             7d    0.02
# 15   Tether USDt            30d   -0.02
# 16   Tether USDt            60d    0.01
# 17   Tether USDt            90d    0.01
# 18           XRP             1h    0.27
# 19           XRP            24h   -1.75
# 20           XRP             7d    4.95
# 21           XRP            30d  -10.34
# 22           XRP            60d  -14.11
# 23           XRP            90d  -30.28
# 24           BNB             1h    0.01
# 25           BNB            24h   -1.64
# 26           BNB             7d    0.76
# 27           BNB            30d   -5.42
# 28           BNB            60d   -8.61
# 29           BNB            90d  -13.05
# 30        Solana             1h    1.06
# 31        Solana            24h    0.11
# 32        Solana             7d   12.30
# 33        Solana            30d    4.77
# 34        Solana            60d   -9.89
# 35        Solana            90d  -42.38
# 36          USDC             1h   -0.00
# 37          USDC            24h   -0.02
# 38          USDC             7d   -0.01
# 39          USDC            30d   -0.01
# 40          USDC            60d   -0.01
# 41          USDC            90d    0.01
# 42      Dogecoin             1h    0.45
# 43      Dogecoin            24h   -0.44
# 44      Dogecoin             7d   13.23
# 45      Dogecoin            30d   -6.59
# 46      Dogecoin            60d  -25.96
# 47      Dogecoin            90d  -49.98
# 48       Cardano             1h    0.57
# 49       Cardano            24h    2.94
# 50       Cardano             7d   16.06
# 51       Cardano            30d   -2.92
# 52       Cardano            60d   -5.08
# 53       Cardano            90d  -26.95
# 54          TRON             1h    0.14
# 55          TRON            24h    0.50
# 56          TRON             7d   -1.04
# 57          TRON            30d    8.35
# 58          TRON            60d    1.15
# 59          TRON            90d   -4.77
# 60           Sui             1h    1.08
# 61           Sui            24h    8.78
# 62           Sui             7d   53.84
# 63           Sui            30d   35.41
# 64           Sui            60d   -0.16
# 65           Sui            90d  -24.95
# 66     Chainlink             1h    0.95
# 67     Chainlink            24h    0.03
# 68     Chainlink             7d   18.45
# 69     Chainlink            30d   -2.88
# 70     Chainlink            60d  -15.02
# 71     Chainlink            90d  -42.40
# 72     Avalanche             1h    0.60
# 73     Avalanche            24h   -0.97
# 74     Avalanche             7d   14.60
# 75     Avalanche            30d   -3.39
# 76     Avalanche            60d   -9.70
# 77     Avalanche            90d  -39.46
# 78       Stellar             1h    0.64
# 79       Stellar            24h    3.12
# 80       Stellar             7d   15.66
# 81       Stellar            30d   -5.14
# 82       Stellar            60d  -15.67
# 83       Stellar            90d  -36.65
# 84  UNUS SED LEO             1h   -0.03
# 85  UNUS SED LEO            24h    1.59
# 86  UNUS SED LEO             7d    2.03
# 87  UNUS SED LEO            30d   -5.53
# 88  UNUS SED LEO            60d   -5.55
# 89  UNUS SED LEO            90d   -5.46

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df5, kind='point')

# %%
df5 = df[['name','quote.USD.price','timestamp']]
df5 = df5.query("name == 'Ethereum'")
df5
# Out:
#        name  quote.USD.price                  timestamp
# 1  Ethereum         1,760.91 2025-04-24 15:38:35.359235
# 1  Ethereum         1,760.91 2025-04-24 14:56:30.889565

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df5)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
